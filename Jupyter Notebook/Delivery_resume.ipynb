# %%
#爬取全部原始碼
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("file:///C:/Users/iachievedream/Documents/resume/1My104.html").read().decode('utf-8')
soup = BeautifulSoup(html, features='lxml')
month = soup.find_all('div', {"class": "compname_5"})#所需資料-工作公司(compname_5)
for m in month:
    print(m.get_text())

"""
#列印全部html
print(html)

#全部表格資料(content)
soup = BeautifulSoup(html, features='lxml')
month = soup.find_all('div', {"class": "content"})
for m in month:
    print(m.get_text())
    
#部分資料-工作職位(jobname_5)
soup = BeautifulSoup(html, features='lxml')
month = soup.find_all('div', {"class": "jobname_5"})
for m in month:
    print(m.get_text())

#所需資料-工作公司(compname_5)
soup = BeautifulSoup(html, features='lxml')
month = soup.find_all('div', {"class": "compname_5"})
for m in month:
    print(m.get_text())
"""
# Out:
# 公司名稱
# 緯德科技股份有限公司 (TechLink Corporation)
# 創樂科技有限公司
# 皮托科技股份有限公司
# 精秝科科技股份有限公司
# 偉林電子股份有限公司
# 易勝資訊股份有限公司
# 英屬維京群島商傑利資訊科技股份有限公司
# 新加坡商鈦坦科技股份有限公司台灣分公司
# 賽微科技股份有限公司
# 商智資訊股份有限公司
# 葳橋資訊股份有限公司
# 高谷科技有限公司
# 華洋精機股份有限公司
# 柿子紅科技股份有限公司
# 奇果力創研科技有限公司
# '\n#列印全部html\nprint(html)\n\n#全部表格資料(content)\nsoup = BeautifulSoup(html, features=\'lxml\')\nmonth = soup.find_all(\'div\', {"class": "content"})\nfor m in month:\n    print(m.get_text())\n    \n#部分資料-工作職位(jobname_5)\nsoup = BeautifulSoup(html, features=\'lxml\')\nmonth = soup.find_all(\'div\', {"class": "jobname_5"})\nfor m in month:\n    print(m.get_text())\n\n\n#所需資料-工作公司(compname_5)\nsoup = BeautifulSoup(html, features=\'lxml\')\nmonth = soup.find_all(\'div\', {"class": "compname_5"})\nfor m in month:\n    print(m.get_text())\n'

# %%
#爬取全部原始碼
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen

for page in range(1,5): 
    html = urlopen("file:///E:/brother/resume/"+ str(page) +"My104.html").read().decode('utf-8')
    soup = BeautifulSoup(html, features='lxml')
    month = soup.find_all('div', {"class": "joblist_cont"}) #在div區塊中，class=rental_result抓取資料
    #month = soup.find_all('div', {"class": "compname_5"})
    for ele in month:
        #print(m.get_text())
        print(
            ele.find('div', {"class": "date"}).text,
            ele.find('div', {"class":"jobname_5"}).text,
            ele.find('div', {"class":"compname_5"}).text
    )
# Out:
# 10/31
# 培訓軟體工程師(PHP)
#  緯德科技股份有限公司 (TechLink Corporation)
# 10/31
# 初階 Java 工程師 (內湖, 高薪, 需輪班)
#  創樂科技有限公司
# 10/30
# 		                				                			程式設計工程師		                				                	 皮托科技股份有限公司
# 10/30
# 軟體工程師 (歡迎職場新鮮人)
#  精秝科科技股份有限公司
# 10/30
# 軟體研發工程師
#  偉林電子股份有限公司
# 10/23
# 		                				                			Python開發工程師(AI及數據平台開發)		                				                	 易勝資訊股份有限公司
# 10/23
# php工程師 ★歡迎新鮮人，相關科系畢，無經驗可★
#  英屬維京群島商傑利資訊科技股份有限公司
# 10/23
# 軟體工程師 Software Engineer / Programmer(台中市政府旁)
#  新加坡商鈦坦科技股份有限公司台灣分公司
# 10/16
# 軟體工程師( Software Engineer)
#  賽微科技股份有限公司
# 10/16
# java 程式設計師 (高雄)
#  商智資訊股份有限公司
# 10/16
# PHP程式設計師[台中]
#  葳橋資訊股份有限公司
# 10/16
# 		                				                			後端軟體工程師(Back-End Software Engineer)		                				                	 高谷科技有限公司
# 10/16
# 軟體工程師
#  華洋精機股份有限公司
# 10/16
# PHP程式設計師 / 35k~50k
#  柿子紅科技股份有限公司
# 10/16
# 		                				                			網頁前端 / 網頁後端 程式設計師		                				                	 奇果力創研科技有限公司
# 11/04
# 		                				                			前/後端web工程師		                				                	 歐兔歐全球股份有限公司
# 11/04
# PHP工程師
#  準訊科技有限公司
# 11/04
# 軟體開發工程師
#  聯瞻資訊股份有限公司
# 11/03
# 軟體工程師_A(RDSW_140)
#  正文科技股份有限公司
# 11/03
# Java程式設計師(專案-非駐點)
#  前進國際股份有限公司
# 11/03
# 軟體工程師
#  天擎積體電路股份有限公司
# 11/02
# 		                				                			電控工程師_(大陸.蘇州)		                				                	 均華精密工業股份有限公司
# 11/02
# Java軟體工程師(台中)
#  碩網資訊股份有限公司
# 11/02
# 		                				                			培訓軟體工程師_D		                				                	 干城數碼有限公司
# 11/02
# Ogloba - Java 軟體工程師
#  金永立有限公司
# 11/02
# 程式設計工程師-雲林
#  德鴻科技股份有限公司
# 11/01
# 自動化工程師
#  新代科技股份有限公司
# 11/01
# 研發助理(Assistant)
#  安富科技股份有限公司
# 11/01
# 61690-自動化軟體研發工程師
#  QNAP_威聯通科技股份有限公司
# 11/01
# 440-Java程式設計師(新竹縣)
#  兆赫電子股份有限公司
# 11/01
# 軟體設計工程師(竹科,南科 MVC )
#  亦思科技股份有限公司
# 11/01
# JAVA 軟體工程師
#  簡單行動支付股份有限公司
# 11/01
# JAVA工程師
#  凡谷興業有限公司
# 11/01
# 應用程式開發工程師_IABG(台南研發中心)
#  台達電子工業股份有限公司 _DELTA ELECTRONICS INC.
# 10/31
# 		                				                			培訓全端軟體工程師(實習生)		                				                	 賜鴻科技有限公司
# 11/26
# 		                				                			軟體工程師		                				                	 網際之星資訊股份有限公司
# 11/26
# 軟體工程師
#  高誠網路服務股份有限公司
# 11/26
# C/C++ Programmer(高雄)
#  台眾電腦股份有限公司
# 11/26
# JAVA程式設計師(高雄)
#  康大資訊股份有限公司
# 11/26
# [第三事業處] Java 開發工程師 (工作地點:高雄)
#  昊聲訊息技術有限公司
# 11/26
# 		                				                			軟體工程師 (Java)		                				                	 意藍資訊股份有限公司
# 11/26
# APP開發工程師
#  旭峻資訊有限公司
# 11/26
# Python Developer(高雄)
#  台灣新蛋股份有限公司
# 11/17
# Ogloba - Java 軟體工程師
#  金永立有限公司
# 11/17
# Java程式設計師(台北)
#  中鋼集團_網際優勢股份有限公司
# 11/17
# 程式研發工程師
#  104人力銀行_一零四資訊科技股份有限公司
# 11/17
# 高雄軟體園區 - 軟體工程師2
#  精益科技股份有限公司
# 11/17
# Java軟體工程師(高雄)
#  景佳科技有限公司
# 11/14
# 高薪 年收70萬起 程式設計師 一年經驗可 ITS
#  全球人事顧問股份有限公司
# 11/14
# 620_ C++ 工程師
#  神通資訊科技股份有限公司
# 11/13
# 資料科學工程師
#  新視域科技股份有限公司
# 11/13
# AI演算法工程師(新北市)
#  智慧雲端科技股份有限公司
# 11/05
# 		                				                			軟體工程師 (Java)		                				                	 意藍資訊股份有限公司
# 11/05
# 軟體設計工程師
#  全曜財經資訊股份有限公司
# 11/04
# 		                				                			程式設計師		                				                	 豐湛數位科技有限公司
# 11/26
# 		                				                			軟體工程師		                				                	 網際之星資訊股份有限公司
# 11/26
# 軟體工程師
#  高誠網路服務股份有限公司
# 11/26
# C/C++ Programmer(高雄)
#  台眾電腦股份有限公司
# 11/26
# JAVA程式設計師(高雄)
#  康大資訊股份有限公司
# 11/26
# [第三事業處] Java 開發工程師 (工作地點:高雄)
#  昊聲訊息技術有限公司
# 11/26
# 軟體工程師 (Java)
#  意藍資訊股份有限公司
# 11/26
# APP開發工程師
#  旭峻資訊有限公司
# 11/26
# 		                				                			Python Developer(高雄)		                				                	 台灣新蛋股份有限公司
# 11/17
# Ogloba - Java 軟體工程師
#  金永立有限公司
# 11/17
# 		                				                			Java程式設計師(台北)		                				                	 中鋼集團_網際優勢股份有限公司
# 11/17
# 程式研發工程師
#  104人力銀行_一零四資訊科技股份有限公司
# 11/17
# 高雄軟體園區 - 軟體工程師2
#  精益科技股份有限公司
# 11/17
# Java軟體工程師(高雄)
#  景佳科技有限公司
# 11/14
# 高薪 年收70萬起 程式設計師 一年經驗可 ITS
#  全球人事顧問股份有限公司
# 11/14
# 620_ C++ 工程師
#  神通資訊科技股份有限公司
# 11/13
# 資料科學工程師
#  新視域科技股份有限公司
# 11/13
# AI演算法工程師(新北市)
#  智慧雲端科技股份有限公司
# 11/05
# 軟體工程師 (Java)
#  意藍資訊股份有限公司
# 11/05
# 軟體設計工程師
#  全曜財經資訊股份有限公司
# 11/04
# 		                				                			程式設計師		                				                	 豐湛數位科技有限公司

# %% [markdown]
# [第16天網頁解析](https://ithelp.ithome.com.tw/articles/10186119)

# %% [markdown]
# [爬蟲如何用Python蒐集7-11的門市資料?](http://bhan0507.logdown.com/posts/1388351-crawler-how-to-store-data-with-python-collection-7-11)

# %%
import requests
import pandas as pd

# 建立一個縣市的list
city = ['基隆市','台北市','新北市','桃園市','新竹市','新竹縣','苗栗縣','台中市','彰化縣','雲林縣',
        '南投縣','嘉義縣','嘉義市','台南市','高雄市','屏東縣','台東縣','花蓮縣','宜蘭縣','連江縣','金門縣','澎湖縣'
]

#使用迴圈來依序取得每一個城市的門市資訊
for index, city in enumerate(city):
    
    #剛剛在開發者模式觀察到的Post發出的資訊是那些
    data = {
        'strTargetField':'COUNTY',
        'strKeyWords':'%s' % city
    }

    res = requests.post('http://www.ibon.com.tw/retail_inquiry_ajax.aspx', data=data)
    # 第一次迴圈建立dataframe，並將城市填入。資料的形式是table，所以直接使用read_html快速拿下!

    if index == 0:
        df_711_store = pd.read_html(res.text, header=0)[0]
        df_711_store['縣市'] = city
     
    # 第二次迴圈以上就將資訊直接append到dataframe裡
    if index > 0:
        df_711_store_ = pd.read_html(res.text, header=0)[0]
        df_711_store_['縣市'] = city
        df_711_store = df_711_store.append(df_711_store_)
    
    #打印出進度
    print('%2d) %-*s %4d' % (index, 5, city, pd.read_html(res.text, header=0)[0].shape[0]))

#將資料輸出成Excel
df_711_store.to_excel('7-11門市.xlsx', encoding="UTF-8", index=False)

# %%
#新聞焦點
import requests
from bs4 import BeautifulSoup

def main():
    print('蘋果今日焦點')
    dom = requests.get('http://www.appledaily.com.tw/appledaily/hotdaily/headline').text
    soup = BeautifulSoup(dom, 'html5lib')
    for ele in soup.find('ul', 'all').find_all('li'):
        print(
            ele.find('div', 'aht_title_num').text,
            ele.find('div', 'aht_title').text,
            ele.find('div', 'aht_pv_num').text
        )
    print('-----------')
    print('自由今日焦點')
    dom = requests.get('http://news.ltn.com.tw/list/newspaper').text
    soup = BeautifulSoup(dom, 'html5lib')
    for ele in soup.find('ul', 'list').find_all('li'):
        print(ele.find('a', 'tit').text.strip())

if __name__ == '__main__':
    main()
# Out:
# 蘋果今日焦點
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-588e2bc90c60> in <module>
#      21
#      22 if __name__ == '__main__':
# ---> 23     main()
#
# <ipython-input-1-588e2bc90c60> in main()
#      11             ele.find('div', 'aht_title_num').text,
#      12             ele.find('div', 'aht_title').text,
# ---> 13             ele.find('div', 'aht_pv_num').text
#      14         )
#      15     print('-----------')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
#爬取全部原始碼--(爬蟲必備Python基礎)
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("http://www.iiiedu.org.tw/ites/PWC.htm").read().decode('big5')#print(html)--列印全部html
soup = BeautifulSoup(html, features='lxml')
month = soup.find_all('table', {"style": "BORDER-COLLAPSE: collapse"})#全部表格資料
for m in month:
    print(m.get_text())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-4a73f5577976> in <module>
#       3 from urllib.request import urlopen
#       4
# ----> 5 html = urlopen("http://www.iiiedu.org.tw/ites/PWC.htm").read().decode('big5')#print(html)--列印全部html
#       6 soup = BeautifulSoup(html, features='lxml')
#       7 month = soup.find_all('table', {"style": "BORDER-COLLAPSE: collapse"})#全部表格資料
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
#新聞焦點
import requests
from bs4 import BeautifulSoup

def main():
    #for i in range(1,6):一至五頁資料
    dom = requests.get('https://tw.mixrent.com/search.php?q=%E5%8F%B0%E5%8C%97%E5%B8%82%E5%AE%BF%E8%88%8D&pmin=&pmax=&smin=&smax=&page=1').text
    soup = BeautifulSoup(dom, 'html')
    month = soup.find_all('div', {"class": "rental_result"})
    for ele in month:
        print(
            ele.find('span', 'label label-primary').text,
            ele.find('a', 'house_title').text,
        )        
if __name__ == '__main__':
    main()
# Out:
# $ 10000 半伴（西門）ShareHouse
# $ 90000 一樓靜巷店辦近國父紀念館適咖啡輕食事務所
# $ 6500 陽明山行旅優質五星級套房(兼社會住宅)
# $ 4500 東吳或各大學和正職單身女生,官邸豪宅
# $ 8000 國父紀念館捷運/宿舍床位/水電全包
# $ 20000 物流倉儲、工廠、倉庫出租鄰二高安坑交流道
# $ 5500 新北秀山國小正對面
# $ 35000 行天宮站2分鐘/優質裝潢/學生員工宿舍
# $ 8000 限女6單房有廚房(除每房獨立電.包費用)
# $ 5500 近輔大/新莊/學生租屋

# %%
#爬取全部原始碼
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("https://tw.mixrent.com/search.php?q=%E5%8F%B0%E5%8C%97%E5%B8%82%E5%AE%BF%E8%88%8D&pmin=&pmax=&smin=&smax=&page=1").read().decode('utf-8')
#print(html)列印全部html
soup = BeautifulSoup(html, features='lxml')
month = soup.find_all('div', {"class": "col-xs-12 col-sm-10"}) #台北市宿舍租屋資訊
#month = soup.find_all('span', {"class": "label label-primary"}) 台北市宿舍租屋房價
#month = soup.find_all('div', {"id": "search_box"})全部表格資料
for m in month:
    print(m.get_text())

"""
for i in range(1,6):
    html = urlopen("https://tw.mixrent.com/search.php?q=%E5%8F%B0%E5%8C%97%E5%B8%82%E5%AE%BF%E8%88%8D&pmin=&pmax=&smin=&smax=&page="+"i").read().decode('utf-8')
    soup = BeautifulSoup(html, features='lxml')
    month = soup.find_all('div', {"class": "col-xs-12 col-sm-10"}) #台北市宿舍租屋資訊
    for m in month:
        print(m.get_text())    
"""
# Out:
# 半伴（西門）ShareHouse
#
#
# 591 - https://rent.591.com.tw/rent-detail-7864786.html
#
#
# 一樓靜巷店辦近國父紀念館適咖啡輕食事務所
#
#
# 591 - https://rent.591.com.tw/rent-detail-7751350.html
#
#
# 陽明山行旅優質五星級套房(兼社會住宅)
#
#
# 591 - https://rent.591.com.tw/rent-detail-7904266.html
#
#
# 東吳或各大學和正職單身女生,官邸豪宅
#
#
# 591 - https://rent.591.com.tw/rent-detail-7861496.html
#
#
# 國父紀念館捷運/宿舍床位/水電全包
#
#
# 591 - https://rent.591.com.tw/rent-detail-7983145.html
#
#
# 物流倉儲、工廠、倉庫出租鄰二高安坑交流道
#
#
# 591 - https://rent.591.com.tw/rent-detail-7841944.html
#
#
# 新北秀山國小正對面
#
#
# 591 - https://rent.591.com.tw/rent-detail-8062478.html
#
#
# 行天宮站2分鐘/優質裝潢/學生員工宿舍
#
#
# 591 - https://rent.591.com.tw/rent-detail-7984151.html
#
#
# 限女6單房有廚房(除每房獨立電.包費用)
#
#
# 591 - https://rent.591.com.tw/rent-detail-8049595.html
#
#
# 近輔大/新莊/學生租屋
#
#
# 591 - https://rent.591.com.tw/rent-detail-8004844.html
# '\nfor i in range(1,6):\n    html = urlopen("https://tw.mixrent.com/search.php?q=%E5%8F%B0%E5%8C%97%E5%B8%82%E5%AE%BF%E8%88%8D&pmin=&pmax=&smin=&smax=&page="+"i").read().decode(\'utf-8\')\n    soup = BeautifulSoup(html, features=\'lxml\')\n    month = soup.find_all(\'div\', {"class": "col-xs-12 col-sm-10"}) #台北市宿舍租屋資訊\n    for m in month:\n        print(m.get_text())    \n'

# %%
from requests_html import HTMLSession
session = HTMLSession()
url = 'https://www.jianshu.com/p/85f4624485b9'
r = session.get(url)#把这个链接对应的网页整个儿取回来
#print(r.html.text)
r.html.links#查看 links 属性
r.html.absolute_links#“绝对”链接
sel = 'body > div.note > div.post > div.article > div.show-content > div > p:nth-child(4) > a'#Copy -> Copy selector
results = r.html.find(sel)#存到 results 变量中
results #[<Element 'a' href='https://www.jianshu.com/nb/130182' target='_blank'>]
results[0].text#'玉树芝兰'
results[0].absolute_links#显示的结果却是一个集合{'https://www.jianshu.com/nb/130182'}
list(results[0].absolute_links)[0]#想要的结果'https://www.jianshu.com/nb/130182'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c17a579f8f86> in <module>
# ----> 1 from requests_html import HTMLSession
#       2 session = HTMLSession()
#       3 url = 'https://www.jianshu.com/p/85f4624485b9'
#       4 r = session.get(url)#把这个链接对应的网页整个儿取回来
#       5 #print(r.html.text)
#
# ModuleNotFoundError: No module named 'requests_html'
