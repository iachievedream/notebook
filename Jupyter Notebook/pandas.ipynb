# %% [markdown]
# [使用Python進行資料分析](https://ithelp.ithome.com.tw/users/20107514/ironman/1399?page=3)
#
# 使用read_csv()讀取一個CSV的檔案
#
# df = pd.read_csv('./csv檔案位置')
#
# 存至csv
#
# df.to_csv('foo.csv')
#
# import numpy as np
#
# np.random.randn()//用來隨機建立資料：
#
# np.save('my_array', x)//儲存
#
# np.load('my_array.npy')//資料載入

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dates = pd.date_range('20130105', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-05 -0.664887 -0.058517  0.608999 -0.651121
# 2013-01-06 -0.144573  0.251899 -0.278227 -0.190168
# 2013-01-07  0.613496  1.116720 -2.562833  1.699308
# 2013-01-08 -0.271967  0.133063 -1.413255  1.064817
# 2013-01-09  0.279604 -0.606479 -1.989877 -0.393581
# 2013-01-10 -0.547629  0.230171  0.706447  0.493730

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
df.to_csv('foo.csv')
